# %%
# 패키지 imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf 

# %matplotlib inline

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model`_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
Data_set = pd.read_csv("../data/10_Regression/Data_set.csv", encoding="euc-kr")

# %%
Data_set = Data_set.set_index('CUST_ID')

# %%
Data_set['OCCP_NAME_G'].value_counts()
# Out:
# 주부          27565
# 사무직         16581
# 2차산업 종사자     9601
# 자영업          9485
# 3차산업 종사자     8275
# 공무원          5091
# 전문직          5043
# 단순 사무직       4107
# 학생           3835
# 운전직          2126
# 기타           1672
# 고소득 전문직      1223
# *            1189
# 1차산업 종사자     1178
# 기업/단체 임원     1041
# 예체능계 종사자      936
# 단순 노무직        821
# Name: OCCP_NAME_G, dtype: int64

# %%
Data_set = Data_set[Data_set['OCCP_NAME_G'] != '*']

# %%
Data_set
# Out:
#          TARGET  BNK_LNIF_CNT  CPT_LNIF_CNT  SPART_LNIF_CNT  ECT_LNIF_CNT  \
# CUST_ID
# 1             0             1             0               0             0
# 2             0             1             0               0             0
# 3             0             0             1               3             2
# 4             1             0             2               4             2
# 5             0             4             0               0             0
# ...         ...           ...           ...             ...           ...
# 102248        0             1             0               2             2
# 102249        0             2             0               0             0
# 102250        0             1             0               0             0
# 102251        0             0             0               1             1
# 102252        0             1             0               0             0
#
#          TOT_LNIF_AMT  TOT_CLIF_AMT  BNK_LNIF_AMT  CPT_LNIF_AMT  \
# ...

# %%
Data_handle = Data_set.dropna(axis=0)

# %%
Data_handle['TARGET'].value_counts()
# Out:
# 0    25288
# 1      981
# Name: TARGET, dtype: int64

# %%
Data_set['TARGET'].value_counts()
# Out:
# 0    94801
# 1     4243
# Name: TARGET, dtype: int64

# %%
Data_y = Data_handle.iloc[:,0]
Data_X = Data_handle.iloc[:,1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(Data_X, 
                                                    Data_y, 
                                                    test_size=0.3, 
                                                    random_state=1234)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-4f43b6be5f87> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(Data_X,
#       2                                                     Data_y,
#       3                                                     test_size=0.3,
#       4                                                     random_state=1234)
#
# NameError: name 'train_test_split' is not defined

# %%
RFC_gs = RandomizedSearchCV(RFC,
                           param_distributions = rf_param_grid,
                           cv=kfold, scoring='accuracy',
                           n_jobs=-1, random_state=42)

# %%
RFC_gs_best.score(X_train, y_train)
