# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pylab as plt

# %%
import seaborn as sns
sns.set()

# %%
import tensorflow as tf

import sklearn
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv("../../project_data/galaxy_train.csv", index_col='id')

# %%
label_dict = {val: i for i, val in enumerate(unique_labels)}
label_dict
# Out:
# {'QSO': 0,
#  'STAR_RED_DWARF': 1,
#  'SERENDIPITY_BLUE': 2,
#  'STAR_BHB': 3,
#  'STAR_CATY_VAR': 4,
#  'SERENDIPITY_DISTANT': 5,
#  'GALAXY': 6,
#  'SPECTROPHOTO_STD': 7,
#  'REDDEN_STD': 8,
#  'ROSAT_D': 9,
#  'STAR_WHITE_DWARF': 10,
#  'SERENDIPITY_RED': 11,
#  'STAR_CARBON': 12,
#  'SERENDIPITY_FIRST': 13,
#  'STAR_BROWN_DWARF': 14,
#  'STAR_SUB_DWARF': 15,
#  'SKY': 16,
#  'SERENDIPITY_MANUAL': 17,
#  'STAR_PN': 18}

# %%
i2lb = {v:k for k, v in label_dict.items()}
i2lb
# Out:
# {0: 'QSO',
#  1: 'STAR_RED_DWARF',
#  2: 'SERENDIPITY_BLUE',
#  3: 'STAR_BHB',
#  4: 'STAR_CATY_VAR',
#  5: 'SERENDIPITY_DISTANT',
#  6: 'GALAXY',
#  7: 'SPECTROPHOTO_STD',
#  8: 'REDDEN_STD',
#  9: 'ROSAT_D',
#  10: 'STAR_WHITE_DWARF',
#  11: 'SERENDIPITY_RED',
#  12: 'STAR_CARBON',
#  13: 'SERENDIPITY_FIRST',
#  14: 'STAR_BROWN_DWARF',
#  15: 'STAR_SUB_DWARF',
#  16: 'SKY',
#  17: 'SERENDIPITY_MANUAL',
#  18: 'STAR_PN'}

# %%
unique_labels = train['type'].unique()
unique_labels
# Out:
# array(['QSO', 'STAR_RED_DWARF', 'SERENDIPITY_BLUE', 'STAR_BHB',
#        'STAR_CATY_VAR', 'SERENDIPITY_DISTANT', 'GALAXY',
#        'SPECTROPHOTO_STD', 'REDDEN_STD', 'ROSAT_D', 'STAR_WHITE_DWARF',
#        'SERENDIPITY_RED', 'STAR_CARBON', 'SERENDIPITY_FIRST',
#        'STAR_BROWN_DWARF', 'STAR_SUB_DWARF', 'SKY', 'SERENDIPITY_MANUAL',
#        'STAR_PN'], dtype=object)

# %%
data_psfMag = data.loc[:,"psfMag_u":"psfMag_z"]
data_fiberMag = data.loc[:,"fiberMag_u":"fiberMag_z"]
data_petroMag = data.loc[:,"petroMag_u":"petroMag_z"]
data_modelMag = data.loc[:,"modelMag_u":"modelMag_z"]

# %%
scaler = StandardScaler()
labels = train['type']
train = train.drop(columns=['fiberID', 'type'])

# %%
train.head()
# Out:
#      psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# id
# 0   23.198224  21.431953  21.314148  21.176553  21.171444   22.581309
# 1   21.431355  20.708104  20.678850  20.703420  20.473229   21.868797
# 2   17.851451  16.727898  16.679677  16.694640  16.641788   18.171890
# 3   20.789900  20.040371  19.926909  19.843840  19.463270   21.039030
# 4   26.454969  23.058767  21.471406  19.504961  18.389096   25.700632
#
#     fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  petroMag_u  petroMag_g  \
# id
# 0    21.644453   21.657571   21.387653   21.572827   22.504317   21.431636
# 1    21.029773   20.967054   20.937731   21.063646   21.360701   20.778968
# 2    17.033098   16.999682   17.095999   17.076449   17.867253   16.738784
# 3    20.317165   20.217898   20.073852   19.794505   20.433907   19.993727
# 4    23.629122   21.742750   19.861718   18.810375   25.859229   22.426929
#
#     petroMag_r  petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  \
# id
# ...

# %%
_mat = scaler.fit_transform(train)
train = pd.DataFrame(_mat, columns=train.columns, index=train.index)

# %%
train.head()
# Out:
#     psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  fiberMag_u  fiberMag_g  \
# id
# 0   0.002522  0.017736  0.022913  0.026865  0.028350    0.002812    0.003432
# 1   0.002373  0.013079  0.017916  0.022808  0.022707    0.002641    0.002612
# 2   0.002071 -0.012530 -0.013542 -0.011566 -0.008257    0.001755   -0.002722
# 3   0.002319  0.008782  0.012001  0.015437  0.014545    0.002442    0.001661
# 4   0.002796  0.028203  0.024150  0.012532  0.005864    0.003560    0.006081
#
#     fiberMag_r  fiberMag_i  fiberMag_z  petroMag_u  petroMag_g  petroMag_r  \
# id
# 0     0.028019    0.026184    0.024489    0.000844    0.019287    0.030818
# 1     0.020351    0.022507    0.020998   -0.000604    0.015060    0.024765
# 2    -0.023707   -0.008885   -0.006338   -0.005030   -0.011112   -0.018435
# 3     0.012031    0.015448    0.012297   -0.001778    0.009973    0.015467
# 4     0.028965    0.013715    0.005550    0.005094    0.025735    0.032826
#
# ...

# %%
train_x = train
train_y = labels.replace(label_dict)

# %%
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.0003,
)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Input(len(train_x.columns)),
  tf.keras.layers.Dense(256*4, activation='elu'),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(256*4, activation='elu'),
  tf.keras.layers.Dense(256*3, activation='elu'),
  tf.keras.layers.Dropout(0.15),
  tf.keras.layers.Dense(256*3, activation='elu'),
  tf.keras.layers.Dense(256*2, activation='elu'),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(256*2, activation='elu'),
  tf.keras.layers.Dropout(0.15),
  tf.keras.layers.Dense(256*1, activation='elu'),
  tf.keras.layers.Dense(256*1, activation='elu'),
  tf.keras.layers.Dropout(0.15),
  tf.keras.layers.Dense(128, activation='elu'),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(64, activation='elu'),
  tf.keras.layers.Dense(32, activation='elu'),
  tf.keras.layers.Dense(19, activation='softmax')
])

# %%
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_x,
          train_y,
          batch_size=256*3,
          validation_split=0.1,
          epochs=200)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 179991 samples, validate on 20000 samples
# Epoch 1/200
# 179991/179991 [==============================] - 13s 71us/sample - loss: 0.9698 - accuracy: 0.6978 - val_loss: 0.6290 - val_accuracy: 0.7902
# Epoch 2/200
# 179991/179991 [==============================] - 13s 70us/sample - loss: 0.6368 - accuracy: 0.7925 - val_loss: 0.5509 - val_accuracy: 0.8180
# Epoch 3/200
# 179991/179991 [==============================] - 13s 71us/sample - loss: 0.5832 - accuracy: 0.8075 - val_loss: 0.5465 - val_accuracy: 0.8187
# Epoch 4/200
# 179991/179991 [==============================] - 13s 74us/sample - loss: 0.5603 - accuracy: 0.8143 - val_loss: 0.5399 - val_accuracy: 0.8145
# Epoch 5/200
# ...

# %%
test = pd.read_csv('../../project_data/galaxy_test.csv').reset_index(drop=True)
test_ids = test['id']
test = test.drop(columns=['id', 'fiberID'])
test = pd.DataFrame(scaler.transform(test), columns=test.columns, index=test.index)

# %%
pred_mat = model.predict(test)
